# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal-geeks/kunal-geeks/blob/main/Python_Session_Number_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of visualisations
#
# ## Pyplot
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = [0,3,4,6]
ypoints = [5,15,20,25]

plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 6])
print(ypoints)
plt.plot(ypoints, marker = 'o')
plt.show()
# Out:
# [ 3  8  1 10  6]

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Bar Graph

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# # Pie Chart

# %%
y = np.array([45, 20, 20, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# # Histogram

# %%
a = np.array([22, 87, 5, 43, 56,
              73, 55, 54, 11,
              20, 51, 5, 79, 31,
              27])
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a, bins = [0, 25, 50, 75, 100])
 
# Show plot
plt.show()
